# %% [markdown]
# # Trim images to be same size
#
# Necessary to thumbnail down the image becuse the raw or even slightly smaller cropped images cause resnet to have to allocate too much memory ~ 59 GB

# %%
from PIL import Image
import os

import os 
os.makedirs('data/cropData/NoFire')
os.makedirs('data/cropData/Fire')

#Opens the image

def cropIm(fldrIn, fn, fldrOut):
    path = fldrIn + fn
    im = Image.open(path)

    #Specifies the corners of the desired image
    # left = 95
    # top = 98
    # right = 3752
    # bottom = 2281

    left = 150
    top = 150
    right = 150 + 224*16
    bottom = 150 + 224*9

    #Crops the image
    im = im.crop((left, top, right, bottom))
    
    # resize - otherwise renet cant allocate enough memory
    MAX_SIZE = (1024, 1024)
    im.thumbnail(MAX_SIZE)

    print(im.size, fn)
    #Saves the image
    im.save(fldrOut + fn)
    im.close()
# cropIm(fldrIn, fn, fldrOut)

import glob
FireList = []
NoFireList = []

fldrIn = "data/origData/Fire/"
fldrOut = "data/cropData/Fire/"
for fire, fn in enumerate(glob.glob(fldrIn+"*.png")):
    fn_trunc = fn.split('/')[-1]
    FireList.append(fn_trunc)
    cropIm(fldrIn, fn_trunc, fldrOut)
    
print('Count fire files', fire)

fldrIn = "data/origData/NoFire/"
fldrOut = "data/cropData/NoFire/"
for noFire, fn in enumerate(glob.glob(fldrIn+"*.png")):
    fn_trunc = fn.split('/')[-1]
    NoFireList.append(fn_trunc)
    cropIm(fldrIn, fn_trunc, fldrOut)
print('Count NoFire files', noFire)
# Out:
# (1024, 576) Fire_088.png
# (1024, 576) Fire_071.png
# (1024, 576) Fire_062.png
# (1024, 576) Fire_052.png
# (1024, 576) Fire_093.png
# (1024, 576) Fire_019.png
# (1024, 576) Fire_054.png
# (1024, 576) Fire_007.png
# (1024, 576) Fire_040.png
# (1024, 576) Fire_056.png
# (1024, 576) Fire_035.png
# (1024, 576) Fire_009.png
# (1024, 576) Fire_047.png
# (1024, 576) Fire_072.png
# (1024, 576) Fire_024.png
# (1024, 576) Fire_090.png
# (1024, 576) Fire_025.png
# (1024, 576) Fire_011.png
# (1024, 576) Fire_096.png
# (1024, 576) Fire_021.png
# (1024, 576) Fire_043.png
# (1024, 576) Fire_010.png
# (1024, 576) Fire_034.png
# (1024, 576) Fire_023.png
# (1024, 576) Fire_030.png
# (1024, 576) Fire_073.png
# (1024, 576) Fire_036.png
# (1024, 576) Fire_076.png
# (1024, 576) Fire_065.png
# (1024, 576) Fire_027.png
# (1024, 576) Fire_028.png
# (1024, 576) Fire_013.png
# (1024, 576) Fire_020.png
# (1024, 576) Fire_069.png
# (1024, 576) Fire_044.png
# (1024, 576) Fire_080.png
# (1024, 576) Fire_059.png
# (1024, 576) Fire_091.png
# (1024, 576) Fire_094.png
# (1024, 576) Fire_082.png
# (1024, 576) Fire_022.png
# (1024, 576) Fire_005.png
# (1024, 576) Fire_041.png
# (1024, 576) Fire_045.png
# (1024, 576) Fire_086.png
# (1024, 576) Fire_068.png
# (1024, 576) Fire_084.png
# (1024, 576) Fire_003.png
# (1024, 576) Fire_074.png
# (1024, 576) Fire_012.png
# (1024, 576) Fire_081.png
# (1024, 576) Fire_002.png
# (1024, 576) Fire_061.png
# (1024, 576) Fire_006.png
# (1024, 576) Fire_085.png
# (1024, 576) Fire_077.png
# (1024, 576) Fire_029.png
# (1024, 576) Fire_051.png
# (1024, 576) Fire_032.png
# (1024, 576) Fire_064.png
# (1024, 576) Fire_016.png
# (1024, 576) Fire_092.png
# (1024, 576) Fire_057.png
# (1024, 576) Fire_075.png
# (1024, 576) Fire_058.png
# (1024, 576) Fire_008.png
# (1024, 576) Fire_000.png
# (1024, 576) Fire_018.png
# (1024, 576) Fire_087.png
# (1024, 576) Fire_031.png
# (1024, 576) Fire_039.png
# (1024, 576) Fire_017.png
# (1024, 576) Fire_089.png
# (1024, 576) Fire_004.png
# (1024, 576) Fire_042.png
# (1024, 576) Fire_078.png
# (1024, 576) Fire_037.png
# (1024, 576) Fire_055.png
# (1024, 576) Fire_049.png
# (1024, 576) Fire_066.png
# (1024, 576) Fire_026.png
# (1024, 576) Fire_060.png
# (1024, 576) Fire_079.png
# (1024, 576) Fire_063.png
# (1024, 576) Fire_095.png
# (1024, 576) Fire_048.png
# (1024, 576) Fire_067.png
# (1024, 576) Fire_070.png
# (1024, 576) Fire_033.png
# (1024, 576) Fire_014.png
# (1024, 576) Fire_015.png
# (1024, 576) Fire_038.png
# (1024, 576) Fire_001.png
# (1024, 576) Fire_053.png
# (1024, 576) Fire_083.png
# (1024, 576) Fire_050.png
# (1024, 576) Fire_046.png
# Count fire files 96
# (1024, 576) NoFire_067.png
# (1024, 576) NoFire_065.png
# (1024, 576) NoFire_062.png
# (1024, 576) NoFire_007.png
# (1024, 576) NoFire_033.png
# (1024, 576) NoFire_046.png
# (1024, 576) NoFire_078.png
# (1024, 576) NoFire_009.png
# (1024, 576) NoFire_042.png
# (1024, 576) NoFire_066.png
# (1024, 576) NoFire_094.png
# (1024, 576) NoFire_018.png
# (1024, 576) NoFire_081.png
# (1024, 576) NoFire_058.png
# (1024, 576) NoFire_008.png
# (1024, 576) NoFire_082.png
# (1024, 576) NoFire_068.png
# (1024, 576) NoFire_074.png
# (1024, 576) NoFire_032.png
# (1024, 576) NoFire_064.png
# (1024, 576) NoFire_011.png
# (1024, 576) NoFire_077.png
# (1024, 576) NoFire_043.png
# (1024, 576) NoFire_010.png
# (1024, 576) NoFire_005.png
# (1024, 576) NoFire_049.png
# (1024, 576) NoFire_034.png
# (1024, 576) NoFire_086.png
# (1024, 576) NoFire_051.png
# (1024, 576) NoFire_000.png
# (1024, 576) NoFire_091.png
# (1024, 576) NoFire_036.png
# (1024, 576) NoFire_072.png
# (1024, 576) NoFire_090.png
# (1024, 576) NoFire_075.png
# (1024, 576) NoFire_035.png
# (1024, 576) NoFire_084.png
# (1024, 576) NoFire_001.png
# (1024, 576) NoFire_063.png
# (1024, 576) NoFire_060.png
# (1024, 576) NoFire_024.png
# (1024, 576) NoFire_015.png
# (1024, 576) NoFire_092.png
# (1024, 576) NoFire_057.png
# (1024, 576) NoFire_027.png
# (1024, 576) NoFire_080.png
# (1024, 576) NoFire_132.png
# (1024, 576) NoFire_073.png
# (1024, 576) NoFire_131.png
# (1024, 576) NoFire_047.png
# (1024, 576) NoFire_013.png
# (1024, 576) NoFire_052.png
# (1024, 576) NoFire_020.png
# (1024, 576) NoFire_045.png
# (1024, 576) NoFire_095.png
# (1024, 576) NoFire_059.png
# (1024, 576) NoFire_096.png
# (1024, 576) NoFire_023.png
# (1024, 576) NoFire_016.png
# (1024, 576) NoFire_048.png
# (1024, 576) NoFire_079.png
# (1024, 576) NoFire_041.png
# (1024, 576) NoFire_040.png
# (1024, 576) NoFire_076.png
# (1024, 576) NoFire_061.png
# (1024, 576) NoFire_085.png
# (1024, 576) NoFire_030.png
# (1024, 576) NoFire_071.png
# (1024, 576) NoFire_028.png
# (1024, 576) NoFire_054.png
# (1024, 576) NoFire_070.png
# (1024, 576) NoFire_089.png
# (1024, 576) NoFire_037.png
# (1024, 576) NoFire_069.png
# (1024, 576) NoFire_130.png
# (1024, 576) NoFire_031.png
# (1024, 576) NoFire_133.png
# (1024, 576) NoFire_012.png
# (1024, 576) NoFire_056.png
# (1024, 576) NoFire_029.png
# (1024, 576) NoFire_021.png
# (1024, 576) NoFire_038.png
# (1024, 576) NoFire_002.png
# (1024, 576) NoFire_017.png
# (1024, 576) NoFire_004.png
# (1024, 576) NoFire_006.png
# (1024, 576) NoFire_022.png
# (1024, 576) NoFire_055.png
# (1024, 576) NoFire_087.png
# (1024, 576) NoFire_019.png
# (1024, 576) NoFire_044.png
# (1024, 576) NoFire_050.png
# (1024, 576) NoFire_025.png
# (1024, 576) NoFire_093.png
# (1024, 576) NoFire_083.png
# (1024, 576) NoFire_003.png
# (1024, 576) NoFire_088.png
# (1024, 576) NoFire_039.png
# (1024, 576) NoFire_014.png
# (1024, 576) NoFire_053.png
# (1024, 576) NoFire_026.png
# Count NoFire files 100
